# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivaram17/100DaysOfAdvancedPythonCoding/blob/main/10056AdvancedPython_NumpyArrayObjects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# np universal func
import numpy as np
arr = np.arange(10)*5
arr1 = np.sqrt(arr)
arr2 = np.exp(arr1)
remainder, wholepart = np.modf(arr)
remainder
wholepart
np.maximum(arr1, arr)
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.])

# %%
# Array oriented programming
import numpy as np
points = np.arange(-5,5, 0.01) # 1000 equally spaced points
xs, ys = np.meshgrid(points, points)
xs

# sqrt of x**2 + y**2
a = np.sqrt(xs**2 + ys**2)

# matplotlib
import matplotlib.pyplot as plt
plt.imshow(a, cmap=plt.cm.gray);
plt.title('Image plot of $\sqrt{x^2 + y^2}$ for a grid values')
# Out:
# Text(0.5, 1.0, 'Image plot of $\\sqrt{x^2 + y^2}$ for a grid values')
